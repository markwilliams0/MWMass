# %%
from urllib import urlencode
from urllib import urlretrieve

from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.table import Table
import numpy as np
from IPython.display import Image

from astropy.visualization import astropy_mpl_style
import matplotlib.pyplot as plt
plt.style.use(astropy_mpl_style)
# %matplotlib inline

# %%
hcg7_center = SkyCoord.from_name('M97')

# %%
type(hcg7_center)
# Out:
# astropy.coordinates.sky_coordinate.SkyCoord

# %%
dir(hcg7_center)
# Out:
# ['T',
#  '__abstractmethods__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__format__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__len__',
#  '__module__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_cache',
#  '_abc_negative_cache',
#  '_abc_negative_cache_version',
#  '_abc_registry',
#  '_apply',
#  '_extra_frameattr_names',
#  '_parse_inputs',
#  '_sky_coord_frame',
#  'altaz',
#  'barycentrictrueecliptic',
#  'cache',
#  'cartesian',
#  'cirs',
#  'copy',
#  'data',
#  u'dec',
#  u'default_differential',
#  u'default_representation',
#  'diagonal',
#  u'distance',
#  'equinox',
#  'fk4',
#  'fk4noeterms',
#  'fk5',
#  'flatten',
#  'frame',
#  'frame_attributes',
#  u'frame_specific_representation_info',
#  'from_name',
# ...

# %%
print(hcg7_center.ra, hcg7_center.dec)
print(hcg7_center.ra.hour, hcg7_center.dec)
# Out:
# (<Longitude 168.69880209 deg>, <Latitude 55.0190237 deg>)
# (11.246586806144002, <Latitude 55.0190237 deg>)

# %%
type(hcg7_center.ra), type(hcg7_center.dec)
# Out:
# (astropy.coordinates.angles.Longitude, astropy.coordinates.angles.Latitude)

# %%
hcg7_center.ra.hour
# Out:
# 11.246586806144002

# %%
from urllib import urlencode
from urllib import urlretrieve

from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.table import Table
import numpy as np
from IPython.display import Image

from astropy.visualization import astropy_mpl_style
import matplotlib.pyplot as plt
plt.style.use(astropy_mpl_style)
# %matplotlib inline

M81_center = SkyCoord.from_name('M81')
M82_center = SkyCoord.from_name('M82')

im_size = 80*u.arcmin
im_w = 1080
im_h = 1920
cutoutbaseurl = 'http://skyservice.pha.jhu.edu/DR12/ImgCutout/getjpeg.aspx'
query_string = urlencode(dict(ra=M81_center.ra.deg,
                                 dec=(M81_center.dec.deg+M82_center.dec.deg)/2,
                                 width=im_w, height=im_h,
                                 scale=im_size.to(u.arcsec).value/im_h))
url = cutoutbaseurl + '?' + query_string

urlretrieve(url, 'M81.jpg')

Image('M81.jpg')

# %%
from urllib import urlencode
from urllib import urlretrieve

from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.table import Table
import numpy as np
from IPython.display import Image

from astropy.visualization import astropy_mpl_style
import matplotlib.pyplot as plt
plt.style.use(astropy_mpl_style)
# %matplotlib inline

RR43 = SkyCoord(28.380401381732053*u.deg, -0.5718159605659159*u.deg, frame='icrs')
RR01 = SkyCoord(21.815664147520245*u.deg, -10.531723782165269*u.deg, frame='icrs')
RRxx = SkyCoord(197.77829315077435*u.deg, -3.0018996304528285*u.deg, frame='icrs')

############

im_size = 0.1*u.arcmin
im_w = 1920
im_h = 1080
cutoutbaseurl = 'http://skyservice.pha.jhu.edu/DR12/ImgCutout/getjpeg.aspx'
query_string = urlencode(dict(ra=RRxx.ra.deg,
                              dec=RRxx.dec.deg,
                              width=im_w, height=im_h,
                              scale=im_size.to(u.arcsec).value/im_h))
url = cutoutbaseurl + '?' + query_string

urlretrieve(url, 'groovy_stuff.jpg')

############

Image('groovy_stuff.jpg')
